# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('house rice india csv.zip')

# %%
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# 1             2920      4000               1.5                   0
# 2             2910      9480               1.5                   0
# 3             3310     42998               2.0                   0
# 4             2710      4500               1.5                   0
# ...            ...       ...               ...                 ...
# 14615         1556     20000               1.0                   0
# 14616         1680      7000               1.5                   0
# 14617         1070      6120               1.0                   0
# 14618         1030      6621               1.0                   0
# 14619          900      4770               1.0                   0
#
#        number of views  condition of the house  ...  Built Year  \
# 0                    4                       5  ...        1921
# 1                    0                       5  ...        1909
# 2                    0                       3  ...        1939
# 3                    0                       3  ...        2001
# 4                    0                       4  ...        1929
# ...                ...                     ...  ...         ...
# 14615                0                       4  ...        1957
# 14616                0                       4  ...        1968
# 14617                0                       3  ...        1962
# 14618                0                       4  ...        1955
# 14619                0                       3  ...        1969
#
#        Renovation Year  Postal Code  Lattitude  Longitude  living_area_renov  \
# 0                    0       122003    52.8645   -114.557               2880
# 1                    0       122004    52.8878   -114.470               2470
# 2                    0       122004    52.8852   -114.468               2940
# 3                    0       122005    52.9532   -114.321               3350
# 4                    0       122006    52.9047   -114.485               2060
# ...                ...          ...        ...        ...                ...
# 14615                0       122066    52.6191   -114.472               2250
# 14616                0       122072    52.5075   -114.393               1540
# 14617                0       122056    52.7289   -114.507               1130
# 14618                0       122042    52.7157   -114.411               1420
# 14619             2009       122018    52.5338   -114.552                900
#
#        lot_area_renov  Number of schools nearby  Distance from the airport  \
# 0                5400                         2                         58
# 1                4000                         2                         51
# 2                6600                         1                         53
# 3               42847                         3                         76
# 4                4500                         1                         51
# ...               ...                       ...                        ...
# 14615           17286                         3                         76
# 14616            7480                         3                         59
# 14617            6120                         2                         64
# 14618            6631                         3                         54
# 14619            3480                         2                         55
#
#          Price
# 0      2380000
# 1      1400000
# 2      1200000
# 3       838000
# 4       805000
# ...        ...
# 14615   221700
# 14616   219200
# 14617   209000
# 14618   205000
# 14619   146000
#
# [14620 rows x 23 columns]

# %%
df.dtypes

# %%
from ast import increment_lineno
#MATPLOTLIB
import matplotlib.pyplot as plt
# %matplotlib inline
#seaborn
import seaborn as snsf

# %%
plt.scatter(df.index,df['Price'])
plt.show()

# %%
sns.scatterplot(x=df.index,y=df['Price'],hue=df['number of floors'])
# Out:
# <Axes: ylabel='Price'>

# %%
plt.figure(figsize=(6,6))
plt.title('line plot of Price')
plt.xlabel('index',fontsize=20)
plt.ylabel('Price',fontsize=20)
plt.plot(df.index,df['Price'],markevery=1,marker='d')
for name, group in df.groupby('number of floors'):
    plt.plot(group.index,group['Price'], label=name,markevery=1,marker='d')
plt.legend()
plt.show()

# %%
sns.stripplot(x=df['number of floors'],y=df['Price'])
# Out:
# <Axes: xlabel='number of floors', ylabel='Price'>

# %%
plt.hist(df['Price'])
# Out:
# (array([1.2916e+04, 1.4260e+03, 1.9100e+02, 6.0000e+01, 1.9000e+01,
#         2.0000e+00, 2.0000e+00, 1.0000e+00, 1.0000e+00, 2.0000e+00]),
#  array([  78000.,  840200., 1602400., 2364600., 3126800., 3889000.,
#         4651200., 5413400., 6175600., 6937800., 7700000.]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(5,5))
df['Price'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
plt.boxplot(df['Price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f14eb9861c0>,
#   <matplotlib.lines.Line2D at 0x7f14eb986460>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f14eb986700>,
#   <matplotlib.lines.Line2D at 0x7f14eb9869a0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f14eb97fee0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f14eb986c40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f14eb986ee0>],
#  'means': []}

# %%
df['Price'].value_counts().plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# # New Section

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import math

# %%
df=pd.read_csv('house rice india csv.zip')

# %%
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# 1             2920      4000               1.5                   0
# 2             2910      9480               1.5                   0
# 3             3310     42998               2.0                   0
# 4             2710      4500               1.5                   0
# ...            ...       ...               ...                 ...
# 14615         1556     20000               1.0                   0
# 14616         1680      7000               1.5                   0
# 14617         1070      6120               1.0                   0
# 14618         1030      6621               1.0                   0
# 14619          900      4770               1.0                   0
#
#        number of views  condition of the house  ...  Built Year  \
# 0                    4                       5  ...        1921
# 1                    0                       5  ...        1909
# 2                    0                       3  ...        1939
# 3                    0                       3  ...        2001
# 4                    0                       4  ...        1929
# ...                ...                     ...  ...         ...
# 14615                0                       4  ...        1957
# 14616                0                       4  ...        1968
# 14617                0                       3  ...        1962
# 14618                0                       4  ...        1955
# 14619                0                       3  ...        1969
#
#        Renovation Year  Postal Code  Lattitude  Longitude  living_area_renov  \
# 0                    0       122003    52.8645   -114.557               2880
# 1                    0       122004    52.8878   -114.470               2470
# 2                    0       122004    52.8852   -114.468               2940
# 3                    0       122005    52.9532   -114.321               3350
# 4                    0       122006    52.9047   -114.485               2060
# ...                ...          ...        ...        ...                ...
# 14615                0       122066    52.6191   -114.472               2250
# 14616                0       122072    52.5075   -114.393               1540
# 14617                0       122056    52.7289   -114.507               1130
# 14618                0       122042    52.7157   -114.411               1420
# 14619             2009       122018    52.5338   -114.552                900
#
#        lot_area_renov  Number of schools nearby  Distance from the airport  \
# 0                5400                         2                         58
# 1                4000                         2                         51
# 2                6600                         1                         53
# 3               42847                         3                         76
# 4                4500                         1                         51
# ...               ...                       ...                        ...
# 14615           17286                         3                         76
# 14616            7480                         3                         59
# 14617            6120                         2                         64
# 14618            6631                         3                         54
# 14619            3480                         2                         55
#
#          Price
# 0      2380000
# 1      1400000
# 2      1200000
# 3       838000
# 4       805000
# ...        ...
# 14615   221700
# 14616   219200
# 14617   209000
# 14618   205000
# 14619   146000
#
# [14620 rows x 23 columns]

# %%
x=df['Lattitude']
y=df['Longitude']
data=df['Price']

# %%
x=df['Lattitude']
y=df['Longitude']
data=df['Price']

# %%
sns.scatterplot(data=df, x = 'Lattitude', y ='Longitude', linewidth=0); 
# We set the linewidth to 0, otherwise the lines around the circles
# appear white and wash out the figure. Try with any positive 
# value of linewidth

# %%
sns.regplot(data = df, x = 'Lattitude', y = 'Longitude', fit_reg=False);
plt.show()

# %%
sns.jointplot(data = df, x = 'Lattitude', y = 'Longitude');
plt.show()

# %%
sns.jointplot(data = df, x = 'Lattitude', y = 'Longitude', kind = 'reg');
plt.show()

# %%
sns.jointplot(data = df, x = 'Lattitude', y = 'Longitude', kind = 'hex');
plt.show()

# %% [markdown]
# # New Section

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import math

# %%
df=pd.read_csv('house rice india csv.zip')

# %%
df

# %%
x=df['Lattitude']
y=df['Longitude']
data=df['Price']

# %%
sns.pairplot(df)

# %% [markdown]
# # New Section

# %%
# import the 
import pandas as pd
from matplotlib import cm
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.path as path
import matplotlib.ticker as ticker
import matplotlib.animation as animation
import pandas as pd
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
df=pd.read_csv('house rice india csv.zip')

# %%
df

# %%
x=df['Lattitude']
y=df['Longitude']
data=df['Price']

# %%
# Get numerical and categorical columns
total_columns = df.columns
num_col = df._get_numeric_data().columns
cat_col = list(set(total_columns)-set(num_col))

# %%
# find categorical columns category and their counts
for i in cat_col:
    print(i)
    print(df[i].value_counts())

# %%
# Plot graph for Item_Type category
index = np.arange(6)
fig, ax = plt.subplots(figsize=(15, 8))
list1x = list(dict(df['Price'].value_counts()).keys())
list1y = list(df['Price'].value_counts())
ax.barh(list1x, list1y, alpha=0.7,
         # width = 0.5,
        color=cm.Blues([i / 0.00525 for i in [ 0.00208, 0.00235, 0.00281, 0.00317, 0.00362, 0.00371, 0.00525, 0.00679, 0.00761, 0.00833]])
        )
plt.rcParams.update({'font.size': 10})
rects = ax.patches
for i, label in enumerate(list1y):
    ax.text(label , i, str(label), size=10, ha='left', va='center')

ax.text(0, 1.02, 'Item_Type house rice india Count', transform=ax.transAxes, size=12, weight=600, color='#777777')
ax.xaxis.set_ticks_position('bottom')
ax.tick_params(axis='x', colors='black', labelsize=9)
ax.set_axisbelow(True)
ax.text(0, -0.1, 'Source: https://content/house rice india csv.zip',
        transform=ax.transAxes, size=12, weight=600, color='#777777')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.show()

# %%
print(df[['Lattitude','Longitude']].groupby(['Lattitude']).agg({'Longitude':'mean'}))
# Out:
#            Longitude
# Lattitude
# 52.3859    -113.8360
# 52.3893    -114.1470
# 52.3947    -114.1630
# 52.4075    -114.2120
# 52.4076    -114.2010
# ...              ...
# 53.0071    -114.5290
# 53.0072    -114.5165
# 53.0074    -114.5400
# 53.0075    -114.5550
# 53.0076    -114.5650
#
# [4662 rows x 1 columns]

# %%
print(df[['Lattitude','Longitude']].groupby(['Lattitude']).agg({'Longitude':'median'}))
# Out:
#            Longitude
# Lattitude
# 52.3859    -113.8360
# 52.3893    -114.1470
# 52.3947    -114.1630
# 52.4075    -114.2120
# 52.4076    -114.2010
# ...              ...
# 53.0071    -114.5290
# 53.0072    -114.5165
# 53.0074    -114.5400
# 53.0075    -114.5550
# 53.0076    -114.5650
#
# [4662 rows x 1 columns]

# %%
print(df[['Lattitude','Longitude']].groupby(['Longitude']).agg(lambda x:x.value_counts().index[0]))
# Out:
#            Lattitude
# Longitude
# -114.709     52.5777
# -114.705     52.6242
# -114.704     52.6082
# -114.702     52.6639
# -114.701     52.6585
# ...              ...
# -113.549     52.9376
# -113.542     52.9420
# -113.509     52.9431
# -113.506     52.9405
# -113.505     52.9412
#
# [716 rows x 1 columns]

# %%
for i in num_col:
    print(f"Column: {i} Max_Value: {max(df[i])} Min_Value: {min(df[i])} Range: {round(max(df[i]) - min(df[i]),2)}")
# Out:
# Column: id Max_Value: 6762831616 Min_Value: 6762810020 Range: 21596
# Column: Date Max_Value: 42734 Min_Value: 42491 Range: 243
# Column: number of bedrooms Max_Value: 33 Min_Value: 1 Range: 32
# Column: number of bathrooms Max_Value: 8.0 Min_Value: 0.5 Range: 7.5
# Column: living area Max_Value: 13540 Min_Value: 370 Range: 13170
# Column: lot area Max_Value: 1074218 Min_Value: 520 Range: 1073698
# Column: number of floors Max_Value: 3.5 Min_Value: 1.0 Range: 2.5
# Column: waterfront present Max_Value: 1 Min_Value: 0 Range: 1
# Column: number of views Max_Value: 4 Min_Value: 0 Range: 4
# Column: condition of the house Max_Value: 5 Min_Value: 1 Range: 4
# Column: grade of the house Max_Value: 13 Min_Value: 4 Range: 9
# Column: Area of the house(excluding basement) Max_Value: 9410 Min_Value: 370 Range: 9040
# Column: Area of the basement Max_Value: 4820 Min_Value: 0 Range: 4820
# Column: Built Year Max_Value: 2015 Min_Value: 1900 Range: 115
# Column: Renovation Year Max_Value: 2015 Min_Value: 0 Range: 2015
# Column: Postal Code Max_Value: 122072 Min_Value: 122003 Range: 69
# Column: Lattitude Max_Value: 53.0076 Min_Value: 52.3859 Range: 0.62
# Column: Longitude Max_Value: -113.505 Min_Value: -114.709 Range: 1.2
# Column: living_area_renov Max_Value: 6110 Min_Value: 460 Range: 5650
# Column: lot_area_renov Max_Value: 560617 Min_Value: 651 Range: 559966
# Column: Number of schools nearby Max_Value: 3 Min_Value: 1 Range: 2
# Column: Distance from the airport Max_Value: 80 Min_Value: 50 Range: 30
# Column: Price Max_Value: 7700000 Min_Value: 78000 Range: 7622000

# %%
for i in num_col:
    print(i , round(df[i].std(),2))
# Out:
# id 6237.57
# Date 67.35
# number of bedrooms 0.94
# number of bathrooms 0.77
# living area 928.28
# lot area 37919.62
# number of floors 0.54
# waterfront present 0.09
# number of views 0.77
# condition of the house 0.66
# grade of the house 1.18
# Area of the house(excluding basement) 833.81
# Area of the basement 448.55
# Built Year 29.49
# Renovation Year 416.22
# Postal Code 19.08
# Lattitude 0.14
# Longitude 0.14
# living_area_renov 691.09
# lot_area_renov 26058.41
# Number of schools nearby 0.82
# Distance from the airport 8.94
# Price 367532.38

# %%
for i in num_col:
    print(i , round(df[i].var(),2))
# Out:
# id 38907339.38
# Date 4535.75
# number of bedrooms 0.88
# number of bathrooms 0.59
# living area 861695.81
# lot area 1437897679.81
# number of floors 0.29
# waterfront present 0.01
# number of views 0.59
# condition of the house 0.44
# grade of the house 1.38
# Area of the house(excluding basement) 695239.05
# Area of the basement 201198.37
# Built Year 869.87
# Renovation Year 173236.31
# Postal Code 364.14
# Lattitude 0.02
# Longitude 0.02
# living_area_renov 477610.04
# lot_area_renov 679040964.56
# Number of schools nearby 0.67
# Distance from the airport 79.85
# Price 135080050939.43

# %%
 df.skew()
# Out:
# id                                       -0.000802
# Date                                      0.143747
# number of bedrooms                        2.663257
# number of bathrooms                       0.556663
# living area                               1.538337
# lot area                                 10.155206
# number of floors                          0.586158
# waterfront present                       11.294672
# number of views                           3.409219
# condition of the house                    1.018018
# grade of the house                        0.777584
# Area of the house(excluding basement)     1.436446
# Area of the basement                      1.609744
# Built Year                               -0.472049
# Renovation Year                           4.359764
# Postal Code                               0.227735
# Lattitude                                -0.523831
# Longitude                                 0.873803
# living_area_renov                         1.081959
# lot_area_renov                            7.774206
# Number of schools nearby                 -0.022519
# Distance from the airport                 0.006114
# Price                                     4.269298
# dtype: float64

# %% [markdown]
# # New Section

# %%
#Find the total number of missing values from the entire dataset
df.isnull().sum().sum()
# Out:
# 0

# %%
df = df.dropna(axis=0)
df.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# Price                                    0
# dtype: int64

# %%
df = df.drop(['Price'],axis=1)
df.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# dtype: int64

# %%
import pandas as pd
import numpy as np
test = pd.Series(range(6))
test.loc[2:4] = np.nan
test
# Out:
# 0    0.0
# 1    1.0
# 2    NaN
# 3    NaN
# 4    NaN
# 5    5.0
# dtype: float64

# %%
# Forward-Fill
test.fillna(method='ffill')
# Out:
# 0    0.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# 5    5.0
# dtype: float64

# %%
# Backward-Fill
test.fillna(method='bfill')
# Out:
# 0    0.0
# 1    1.0
# 2    5.0
# 3    5.0
# 4    5.0
# 5    5.0
# dtype: float64

# %%
test.interpolate()

# %%
import pandas as pd
import numpy as np
X = pd.DataFrame({'Shape':['square', 'square', 'oval', 'circle', np.nan]})

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='most_frequent')
imputer.fit_transform(X)
# Out:
# array([['square'],
#        ['square'],
#        ['oval'],
#        ['circle'],
#        ['square']], dtype=object)

# %%
imputer = SimpleImputer(strategy='constant', fill_value='missing')
imputer.fit_transform(X)
# Out:
# array([['square'],
#        ['square'],
#        ['oval'],
#        ['circle'],
#        ['missing']], dtype=object)

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='mean')
imp.fit([[1, 2], [np.nan, 3], [7, 6]])
# Out:
# SimpleImputer()

# %%
X = [[np.nan, 2], [6, np.nan], [7, 6]]
print(imp.transform(X))
# Out:
# [[4.         2.        ]
#  [6.         3.66666667]
#  [7.         6.        ]]

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
impute_it = IterativeImputer()
impute_it.fit_transform(X)
# Out:
# array([[5.000012, 2.      ],
#        [6.      , 3.999988],
#        [7.      , 6.      ]])

# %%
from sklearn.impute import KNNImputer
impute_knn = KNNImputer(n_neighbors=2)
impute_knn.fit_transform(X)
# Out:
# array([[6.5, 2. ],
#        [6. , 4. ],
#        [7. , 6. ]])
